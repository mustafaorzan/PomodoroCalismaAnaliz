# %%
# %%time
import pandas as pd 
import numpy as np
import datetime

start = datetime.datetime.now()
df = pd.read_excel("Çalışma Çizelgesi v2.xlsx")
df.head()
# Out:
# CPU times: total: 875 ms
# Wall time: 1.65 s
#    Gün  Ay   Yıl     GünAdı  Yapılan  Hedef  ÇalışmaOranı  FreeDay  OffDay
# 0    5  12  2022  Pazartesi        5      6      0.833333        0       0
# 1    6  12  2022       Salı        3      6      0.500000        0       0
# 2    7  12  2022   Çarşamba        0      0      0.000000        0       1
# 3    8  12  2022   Perşembe        0      6      0.000000        0       0
# 4    9  12  2022       Cuma        0      6      0.000000        0       0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 452 entries, 0 to 451
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Gün           452 non-null    int64
#  1   Ay            452 non-null    int64
#  2   Yıl           452 non-null    int64
#  3   GünAdı        452 non-null    object
#  4   Yapılan       452 non-null    int64
#  5   Hedef         452 non-null    int64
#  6   ÇalışmaOranı  452 non-null    float64
#  7   FreeDay       452 non-null    int64
#  8   OffDay        452 non-null    int64
# dtypes: float64(1), int64(7), object(1)
# memory usage: 31.9+ KB

# %%
df['Tarih'] = pd.to_datetime(df['Yıl'].astype(str) + '-' + df['Ay'].astype(str) + '-' + df['Gün'].astype(str))
df['Tarih'] = df['Tarih'].dt.strftime('%d-%m-%Y')
df.head()
# Out:
#    Gün  Ay   Yıl     GünAdı  Yapılan  Hedef  ÇalışmaOranı  FreeDay  OffDay  \
# 0    5  12  2022  Pazartesi        5      6      0.833333        0       0
# 1    6  12  2022       Salı        3      6      0.500000        0       0
# 2    7  12  2022   Çarşamba        0      0      0.000000        0       1
# 3    8  12  2022   Perşembe        0      6      0.000000        0       0
# 4    9  12  2022       Cuma        0      6      0.000000        0       0
#
#         Tarih
# 0  05-12-2022
# 1  06-12-2022
# 2  07-12-2022
# 3  08-12-2022
# 4  09-12-2022

# %%
df.drop(columns=['Gün', 'Ay','Yıl'])
# Out:
#         GünAdı  Yapılan  Hedef  ÇalışmaOranı  FreeDay  OffDay       Tarih
# 0    Pazartesi        5      6      0.833333        0       0  05-12-2022
# 1         Salı        3      6      0.500000        0       0  06-12-2022
# 2     Çarşamba        0      0      0.000000        0       1  07-12-2022
# 3     Perşembe        0      6      0.000000        0       0  08-12-2022
# 4         Cuma        0      6      0.000000        0       0  09-12-2022
# ..         ...      ...    ...           ...      ...     ...         ...
# 447      Pazar        0      0      0.000000        1       0  25-02-2024
# 448  Pazartesi        9      8      1.125000        0       0  26-02-2024
# 449       Salı        4      8      0.500000        0       0  27-02-2024
# 450   Çarşamba        4      8      0.500000        0       0  28-02-2024
# 451   Perşembe        5      8      0.625000        0       0  29-02-2024
#
# [452 rows x 7 columns]

# %%
df = df[['Tarih', 'GünAdı', 'Yapılan', 'Hedef', 'ÇalışmaOranı', 'FreeDay', 'OffDay']]
df.head()
# Out:
#         Tarih     GünAdı  Yapılan  Hedef  ÇalışmaOranı  FreeDay  OffDay
# 0  05-12-2022  Pazartesi        5      6      0.833333        0       0
# 1  06-12-2022       Salı        3      6      0.500000        0       0
# 2  07-12-2022   Çarşamba        0      0      0.000000        0       1
# 3  08-12-2022   Perşembe        0      6      0.000000        0       0
# 4  09-12-2022       Cuma        0      6      0.000000        0       0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 452 entries, 0 to 451
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tarih         452 non-null    object
#  1   GünAdı        452 non-null    object
#  2   Yapılan       452 non-null    int64
#  3   Hedef         452 non-null    int64
#  4   ÇalışmaOranı  452 non-null    float64
#  5   FreeDay       452 non-null    int64
#  6   OffDay        452 non-null    int64
# dtypes: float64(1), int64(4), object(2)
# memory usage: 24.8+ KB

# %%
df['Tarih'] = pd.to_datetime(df['Tarih'], format='%d-%m-%Y')
#df['Tarih'] = df['Tarih'].dt.strftime('%d-%m-%Y')
df.head()
# Out:
#        Tarih     GünAdı  Yapılan  Hedef  ÇalışmaOranı  FreeDay  OffDay
# 0 2022-12-05  Pazartesi        5      6      0.833333        0       0
# 1 2022-12-06       Salı        3      6      0.500000        0       0
# 2 2022-12-07   Çarşamba        0      0      0.000000        0       1
# 3 2022-12-08   Perşembe        0      6      0.000000        0       0
# 4 2022-12-09       Cuma        0      6      0.000000        0       0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 452 entries, 0 to 451
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tarih         452 non-null    datetime64[ns]
#  1   GünAdı        452 non-null    object
#  2   Yapılan       452 non-null    int64
#  3   Hedef         452 non-null    int64
#  4   ÇalışmaOranı  452 non-null    float64
#  5   FreeDay       452 non-null    int64
#  6   OffDay        452 non-null    int64
# dtypes: datetime64[ns](1), float64(1), int64(4), object(1)
# memory usage: 24.8+ KB

# %%
# %%time
df['GünAdı'].value_counts()
# Out:
# CPU times: total: 0 ns
# Wall time: 1 ms
# GünAdı
# Pazartesi    65
# Salı         65
# Çarşamba     65
# Perşembe     65
# Cuma         64
# Cumartesi    64
# Pazar        64
# Name: count, dtype: int64

# %%
# %%time
from matplotlib import pyplot as plt
plt.figure(figsize=(16,8))
plt.grid()
plt.title("Belirlenen Hedefler (Tarihe Göre)")
sns.scatterplot(data=df, x='Tarih', y='Hedef')
# Out:
# CPU times: total: 906 ms
# Wall time: 2.83 s
# <Axes: title={'center': 'Belirlenen Hedefler (Tarihe Göre)'}, xlabel='Tarih', ylabel='Hedef'>

# %%
df['Hedef'].mean()
# Out:
# 4.530973451327434

# %%
df['Yapılan'].mean()
# Out:
# 2.338495575221239

# %%
df['Yapılan'].mean() / df['Hedef'].mean()
# Out:
# 0.51611328125

# %%
# %%time

##### import seaborn as sns
plt.figure(figsize=(16,8))
plt.grid()
plt.title("Yapılan Çalışmalar (Tarihe Göre)")
plt.axhline(y=df['Yapılan'].mean(), color='red') #Çeklien alt çizgi
plt.axhline(y=df['Hedef'].mean(), color='green') #Çeklien üst çizgi
sns.scatterplot(data=df, x='Tarih', y='Yapılan')
# Out:
# CPU times: total: 31.2 ms
# Wall time: 29 ms
# <Axes: title={'center': 'Yapılan Çalışmalar (Tarihe Göre)'}, xlabel='Tarih', ylabel='Yapılan'>

# %%
# %%time

pd.set_option('display.max_rows', df.shape[0]+1)
df[(df['ÇalışmaOranı'] >= (df['Yapılan'].mean() / df['Hedef'].mean())) & (df['Hedef'] >= df['Hedef'].mean()) & (df['Yapılan'] >= df['Yapılan'].mean())]
# Out:
# CPU times: total: 0 ns
# Wall time: 1 ms
#          Tarih     GünAdı  Yapılan  Hedef  ÇalışmaOranı  FreeDay  OffDay
# 0   2022-12-05  Pazartesi        5      6      0.833333        0       0
# 9   2022-12-14   Çarşamba        4      6      0.666667        0       0
# 14  2022-12-19  Pazartesi        5      6      0.833333        0       0
# 15  2022-12-20       Salı        6      6      1.000000        0       0
# 19  2022-12-24  Cumartesi        5      6      0.833333        0       0
# 29  2023-01-03       Salı        6      6      1.000000        0       0
# 31  2023-01-05   Perşembe        7      6      1.166667        0       0
# 35  2023-01-09  Pazartesi        6      8      0.750000        0       0
# 36  2023-01-10       Salı        8      8      1.000000        0       0
# 37  2023-01-11   Çarşamba        5      6      0.833333        0       0
# 38  2023-01-12   Perşembe        7      8      0.875000        0       0
# ...

# %%
# %%time

plt.figure(figsize=(16,8))
plt.grid()
plt.title("Çalışma Oranları (Tarihe Göre)")
sns.scatterplot(data=df, x='Tarih', y='ÇalışmaOranı')
# Out:
# CPU times: total: 31.2 ms
# Wall time: 31 ms
# <Axes: title={'center': 'Çalışma Oranları (Tarihe Göre)'}, xlabel='Tarih', ylabel='ÇalışmaOranı'>

# %%
df[df['ÇalışmaOranı']>1]
# Out:
#          Tarih     GünAdı  Yapılan  Hedef  ÇalışmaOranı  FreeDay  OffDay
# 21  2022-12-26  Pazartesi        4      2      2.000000        0       0
# 24  2022-12-29   Perşembe        6      4      1.500000        0       0
# 31  2023-01-05   Perşembe        7      6      1.166667        0       0
# 77  2023-02-20  Pazartesi        9      8      1.125000        0       0
# 111 2023-03-26      Pazar        6      4      1.500000        0       0
# 191 2023-06-14   Çarşamba        9      8      1.125000        0       0
# 199 2023-06-22   Perşembe        5      4      1.250000        0       0
# 304 2023-10-05   Perşembe        6      4      1.500000        0       0
# 308 2023-10-09  Pazartesi        7      6      1.166667        0       0
# 399 2024-01-08  Pazartesi        9      8      1.125000        0       0
# 448 2024-02-26  Pazartesi        9      8      1.125000        0       0

# %%
df.loc[df['Hedef']==16]
# Out:
#          Tarih     GünAdı  Yapılan  Hedef  ÇalışmaOranı  FreeDay  OffDay
# 189 2023-06-12  Pazartesi        8     16           0.5        0       0

# %%
df.loc[df['Yapılan']>=9]
# Out:
#          Tarih     GünAdı  Yapılan  Hedef  ÇalışmaOranı  FreeDay  OffDay
# 77  2023-02-20  Pazartesi        9      8      1.125000        0       0
# 114 2023-03-29   Çarşamba        9     12      0.750000        0       0
# 191 2023-06-14   Çarşamba        9      8      1.125000        0       0
# 193 2023-06-16       Cuma       10     12      0.833333        0       0
# 197 2023-06-20       Salı       11     12      0.916667        0       0
# 198 2023-06-21   Çarşamba       10     12      0.833333        0       0
# 399 2024-01-08  Pazartesi        9      8      1.125000        0       0
# 448 2024-02-26  Pazartesi        9      8      1.125000        0       0

# %%
df['Yapılan'].value_counts()
# Out:
# Yapılan
# 0     208
# 2      46
# 4      45
# 3      38
# 6      29
# 5      24
# 7      19
# 8      19
# 1      16
# 9       5
# 10      2
# 11      1
# Name: count, dtype: int64

# %%
df['Hedef'].value_counts()
# Out:
# Hedef
# 0     162
# 8     108
# 4      75
# 6      53
# 12     42
# 2       8
# 10      3
# 16      1
# Name: count, dtype: int64

# %%
toplam_calisma = df.groupby('GünAdı')['Yapılan'].sum().reindex(['Pazartesi', 'Salı', 'Çarşamba', 'Perşembe', 'Cuma', 'Cumartesi', 'Pazar']).reset_index()
toplam_calisma
# Out:
#       GünAdı  Yapılan
# 0  Pazartesi      280
# 1       Salı      219
# 2   Çarşamba      201
# 3   Perşembe      189
# 4       Cuma      106
# 5  Cumartesi       39
# 6      Pazar       23

# %%
# %%time

plt.figure(figsize=(16,8))
plt.grid()
plt.title("Günlere Göre Yapılan Çalışmalar")
sns.barplot(data=toplam_calisma, x="GünAdı", y="Yapılan")
# Out:
# CPU times: total: 46.9 ms
# Wall time: 34 ms
# <Axes: title={'center': 'Günlere Göre Yapılan Çalışmalar'}, xlabel='GünAdı', ylabel='Yapılan'>

# %%
toplam_offDay = df.groupby('GünAdı')[['FreeDay','OffDay']].sum().reindex(['Pazartesi', 'Salı', 'Çarşamba', 'Perşembe', 'Cuma', 'Cumartesi', 'Pazar']).reset_index()
toplam_offDay['TotalOffDay'] = toplam_offDay['OffDay'] + toplam_offDay['FreeDay']
toplam_offDay['OrtalamaOffDay'] =  toplam_offDay['TotalOffDay'] /  (df.shape[0] / 7)
toplam_offDay
# Out:
#       GünAdı  FreeDay  OffDay  TotalOffDay  OrtalamaOffDay
# 0  Pazartesi        0       8            8        0.123894
# 1       Salı        0       8            8        0.123894
# 2   Çarşamba        0      11           11        0.170354
# 3   Perşembe        0      13           13        0.201327
# 4       Cuma        1      20           21        0.325221
# 5  Cumartesi       37      11           48        0.743363
# 6      Pazar       41      12           53        0.820796

# %%
df[(df['FreeDay']==1) & (df['GünAdı'] == 'Cuma')]
# Out:
#          Tarih GünAdı  Yapılan  Hedef  ÇalışmaOranı  FreeDay  OffDay
# 116 2023-03-31   Cuma        0      0           0.0        1       0

# %%
totalOff = toplam_offDay['TotalOffDay'].sum()
print("Toplam Boş Gün:",totalOff)
print("Ortalama",( round((totalOff / len(df)) , 2) ), "Gün Boş Geçmiş")
# Out:
# Toplam Boş Gün: 162
# Ortalama 0.36 Gün Boş Geçmiş

# %%
# %%time

plt.figure(figsize=(16,8))
plt.title("Günlere Göre Boş Günler (OffDay + FreeDay)")
plt.grid()
sns.barplot(data=toplam_offDay, x="GünAdı", y="TotalOffDay")
# Out:
# CPU times: total: 31.2 ms
# Wall time: 34 ms
# <Axes: title={'center': 'Günlere Göre Boş Günler (OffDay + FreeDay)'}, xlabel='GünAdı', ylabel='TotalOffDay'>

# %%
toplam_hedef = df.groupby('GünAdı')['Hedef'].sum().reindex(['Pazartesi', 'Salı', 'Çarşamba', 'Perşembe', 'Cuma', 'Cumartesi', 'Pazar']).reset_index()
toplam_hedef['OrtalamaHedef'] =  toplam_hedef['Hedef'] /  (df.shape[0] / 7)
toplam_hedef
# Out:
#       GünAdı  Hedef  OrtalamaHedef
# 0  Pazartesi    420       6.504425
# 1       Salı    420       6.504425
# 2   Çarşamba    398       6.163717
# 3   Perşembe    380       5.884956
# 4       Cuma    288       4.460177
# 5  Cumartesi     82       1.269912
# 6      Pazar     60       0.929204

# %%
# %%time

plt.figure(figsize=(16,8))
plt.title("Günlere Göre Belirlenmiş Hedefler")
plt.grid()
sns.barplot(data=toplam_hedef, x="GünAdı", y="Hedef")
# Out:
# CPU times: total: 31.2 ms
# Wall time: 34 ms
# <Axes: title={'center': 'Günlere Göre Belirlenmiş Hedefler'}, xlabel='GünAdı', ylabel='Hedef'>

# %%
genel_hedef_yuzde = df.groupby('GünAdı')[['Yapılan','Hedef']].sum().reindex(['Pazartesi', 'Salı', 'Çarşamba', 'Perşembe', 'Cuma', 'Cumartesi', 'Pazar']).reset_index()
genel_hedef_yuzde['CalismaOran'] = genel_hedef_yuzde['Yapılan'] / genel_hedef_yuzde['Hedef']
genel_hedef_yuzde['CalismaOran'] =  round(genel_hedef_yuzde['CalismaOran'], 3) * 100
genel_hedef_yuzde['YapılanOrt'] =  genel_hedef_yuzde['Yapılan'] /  (df.shape[0] / 7)
genel_hedef_yuzde['HedefOrt'] =  genel_hedef_yuzde['Hedef'] /  (df.shape[0] / 7)
genel_hedef_yuzde
# Out:
#       GünAdı  Yapılan  Hedef  CalismaOran  YapılanOrt  HedefOrt
# 0  Pazartesi      280    420         66.7    4.336283  6.504425
# 1       Salı      219    420         52.1    3.391593  6.504425
# 2   Çarşamba      201    398         50.5    3.112832  6.163717
# 3   Perşembe      189    380         49.7    2.926991  5.884956
# 4       Cuma      106    288         36.8    1.641593  4.460177
# 5  Cumartesi       39     82         47.6    0.603982  1.269912
# 6      Pazar       23     60         38.3    0.356195  0.929204

# %%
# %%time

plt.figure(figsize=(16,8))
plt.title("Günlere Göre Gerçekleşen Çalışma Oranları")
plt.grid()
sns.barplot(data=genel_hedef_yuzde, x="GünAdı", y="CalismaOran")
# Out:
# CPU times: total: 31.2 ms
# Wall time: 35 ms
# <Axes: title={'center': 'Günlere Göre Gerçekleşen Çalışma Oranları'}, xlabel='GünAdı', ylabel='CalismaOran'>

# %%
df_bos = df[(df['Yapılan'] == 0) & (df['Hedef']!=0)]
df_bos
# Out:
#          Tarih     GünAdı  Yapılan  Hedef  ÇalışmaOranı  FreeDay  OffDay
# 3   2022-12-08   Perşembe        0      6           0.0        0       0
# 4   2022-12-09       Cuma        0      6           0.0        0       0
# 5   2022-12-10  Cumartesi        0      6           0.0        0       0
# 6   2022-12-11      Pazar        0      6           0.0        0       0
# 16  2022-12-21   Çarşamba        0      6           0.0        0       0
# 23  2022-12-28   Çarşamba        0      4           0.0        0       0
# 44  2023-01-18   Çarşamba        0      4           0.0        0       0
# 58  2023-02-01   Çarşamba        0      8           0.0        0       0
# 60  2023-02-03       Cuma        0      4           0.0        0       0
# 95  2023-03-10       Cuma        0      4           0.0        0       0
# 130 2023-04-14       Cuma        0     12           0.0        0       0
# 134 2023-04-18       Salı        0      4           0.0        0       0
# ...

# %%
df_bos.shape
# Out:
# (46, 7)

# %%
# %%time

df_bosGunler = df_bos['GünAdı'].value_counts().reindex(['Pazartesi', 'Salı', 'Çarşamba', 'Perşembe', 'Cuma', 'Cumartesi', 'Pazar']).reset_index()
df_bosGunler['Oran'] = df_bosGunler['count'] / (df.shape[0] / 7)
df_bosGunler
# Out:
# CPU times: total: 0 ns
# Wall time: 1 ms
#       GünAdı  count      Oran
# 0  Pazartesi      4  0.061947
# 1       Salı      6  0.092920
# 2   Çarşamba      9  0.139381
# 3   Perşembe      6  0.092920
# 4       Cuma     13  0.201327
# 5  Cumartesi      3  0.046460
# 6      Pazar      5  0.077434

# %%
#Aylık Çalışma + Hedef-Yapılan Grafiği

# %%
# %%time

grouped = df.groupby('GünAdı')

for day, group in grouped:
    plt.figure(figsize=(16,8))  # Her seferinde yeni bir grafik oluştur
    plt.grid()
    plt.plot(group['Tarih'], group['Yapılan'], marker='o', label=day)
    plt.title(f'Günlere Göre Yapılan Çalışmalar- {day}')
    plt.xlabel('Tarih')
    plt.ylabel('Yapılan İşlem Sayısı')
    plt.legend()
    plt.show()
# Out:
# CPU times: total: 1.17 s
# Wall time: 1.19 s

# %%
for day, group in grouped:
    plt.figure(figsize=(16,8))  # Her seferinde yeni bir grafik oluştur
    plt.grid()
    plt.plot(group['Tarih'], group['Hedef'], marker='o', label=day)
    plt.title(f'Günlere Göre Belirlenen Hedefler - {day}')
    plt.xlabel('Tarih')
    plt.ylabel('Hedef')
    plt.legend()
    plt.show()

# %%
# %%time
for day, group in grouped:
    plt.figure(figsize=(16,8))  # Her seferinde yeni bir grafik oluştur
    plt.grid()
    plt.plot(group['Tarih'], group['ÇalışmaOranı'], marker='o', label=day)
    plt.title(f'Günlere Göre Çalışma Oranı - {day}')
    plt.xlabel('Tarih')
    plt.ylabel('Yapılan İşlem Sayısı')
    plt.legend()
    plt.show()
# Out:
# CPU times: total: 1.12 s
# Wall time: 1.13 s

# %%
grouped_df = df.groupby(df['Tarih'].dt.to_period("M")).agg({'Yapılan': 'sum', 'Hedef': 'sum', 'FreeDay': 'sum', 'OffDay': 'sum'}).reset_index()
grouped_df['ÇalışmaOranı'] = grouped_df['Yapılan'] / grouped_df['Hedef'] 
grouped_df['ÇalışmaOranı'] = np.round(grouped_df['ÇalışmaOranı'], 3) * 100
grouped_df['BoşGünler'] = grouped_df['FreeDay'] + grouped_df['OffDay']
#grouped_df['Gün'] = df.groupby(df['Tarih'].dt.to_period("M"))['Tarih'].count().reset_index()
grouped_df= grouped_df[['Tarih','Yapılan', 'Hedef', 'ÇalışmaOranı','BoşGünler']]
grouped_df
# Out:
#       Tarih  Yapılan  Hedef  ÇalışmaOranı  BoşGünler
# 0   2022-12       59    124          47.6          4
# 1   2023-01      101    148          68.2          9
# 2   2023-02       43     76          56.6         19
# 3   2023-03      107    172          62.2         10
# 4   2023-04       76    178          42.7         10
# 5   2023-05      116    224          51.8          7
# 6   2023-06      127    216          58.8          8
# 7   2023-07       34     88          38.6          8
# 8   2023-08        9     50          18.0         18
# 9   2023-09       18     44          40.9         19
# 10  2023-10       71    100          71.0         13
# 11  2023-11       73    154          47.4          8
# 12  2023-12       56    140          40.0         12
# 13  2024-01       91    176          51.7          8
# 14  2024-02       76    158          48.1          9

# %%
grouped_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tarih         15 non-null     period[M]
#  1   Yapılan       15 non-null     int64
#  2   Hedef         15 non-null     int64
#  3   ÇalışmaOranı  15 non-null     float64
#  4   BoşGünler     15 non-null     int64
# dtypes: float64(1), int64(3), period[M](1)
# memory usage: 732.0 bytes

# %%
grouped_df['Tarih'] = grouped_df['Tarih'].dt.to_timestamp()

# %%
# %%time
plt.figure(figsize=(16,8))
plt.grid()
plt.title("Yapılan Çalışmalar (Aylık)")
plt.plot(grouped_df['Tarih'], grouped_df['Hedef'], label='Hedef', color='red', linestyle='--')
plt.plot(grouped_df['Tarih'], grouped_df['Yapılan'], label='Yapılan', color='green', linestyle='--')
sns.scatterplot(data=grouped_df, x='Tarih', y='Yapılan')
sns.scatterplot(data=grouped_df, x='Tarih', y='Hedef')
# Out:
# CPU times: total: 31.2 ms
# Wall time: 40 ms
# <Axes: title={'center': 'Yapılan Çalışmalar (Aylık)'}, xlabel='Tarih', ylabel='Yapılan'>

# %%
from lazypredict.Supervised import LazyRegressor, LazyClassifier
from sklearn.model_selection import train_test_split

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 452 entries, 0 to 451
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tarih         452 non-null    datetime64[ns]
#  1   GünAdı        452 non-null    object
#  2   Yapılan       452 non-null    int64
#  3   Hedef         452 non-null    int64
#  4   ÇalışmaOranı  452 non-null    float64
#  5   FreeDay       452 non-null    int64
#  6   OffDay        452 non-null    int64
# dtypes: datetime64[ns](1), float64(1), int64(4), object(1)
# memory usage: 24.8+ KB

# %%
X = df[['Hedef', 'FreeDay', 'OffDay']]
y = df['Yapılan']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size= 0.20)

# %%
# %%time
reg = LazyRegressor(verbose=0, ignore_warnings = True, custom_metric=None)
models, predictions = reg.fit(X_train, X_test, y_train, y_test)
# Out:
# 100%|██████████| 42/42 [00:01<00:00, 41.46it/s]
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000149 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 14
# [LightGBM] [Info] Number of data points in the train set: 361, number of used features: 3
# [LightGBM] [Info] Start training from score 2.288089
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %%
models
# Out:
#                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# HuberRegressor                               0.60       0.61  1.65        0.01
# LinearSVR                                    0.60       0.61  1.65        0.01
# PassiveAggressiveRegressor                   0.60       0.61  1.65        0.01
# Lars                                         0.59       0.61  1.65        0.01
# LinearRegression                             0.59       0.61  1.65        0.01
# TransformedTargetRegressor                   0.59       0.61  1.65        0.01
# RidgeCV                                      0.59       0.61  1.66        0.00
# Ridge                                        0.59       0.61  1.66        0.01
# BayesianRidge                                0.59       0.61  1.66        0.01
# ElasticNetCV                                 0.59       0.61  1.66        0.05
# LassoCV                                      0.59       0.61  1.66        0.05
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
# %%time
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# CPU times: total: 0 ns
# Wall time: 1 ms
# LinearRegression()

# %%
df['Tahmin'] = model.predict(X)

# %%
df['Dif'] = np.abs(df['Yapılan'] - df['Tahmin'])

# %%
df.head()
# Out:
#        Tarih     GünAdı  Yapılan  Hedef  ÇalışmaOranı  FreeDay  OffDay  \
# 0 2022-12-05  Pazartesi        5      6          0.83        0       0
# 1 2022-12-06       Salı        3      6          0.50        0       0
# 2 2022-12-07   Çarşamba        0      0          0.00        0       1
# 3 2022-12-08   Perşembe        0      6          0.00        0       0
# 4 2022-12-09       Cuma        0      6          0.00        0       0
#
#    Tahmin  Dif
# 0    3.14 1.86
# 1    3.14 0.14
# 2   -0.00 0.00
# 3    3.14 3.14
# 4    3.14 3.14

# %%
print("Yapılan Toplam: " , df['Yapılan'].sum())
print("Tahmin Toplam: " , np.round(df['Tahmin'].sum(), 2))
print("Fark Toplam: " , np.round(df['Dif'].sum(), 2))
print("Fark Ortalama: " , np.round(df['Dif'].mean(), 2))
# Out:
# Yapılan Toplam:  1057
# Tahmin Toplam:  1076.28
# Fark Toplam:  492.63
# Fark Ortalama:  1.09

# %%
df['TahminÇalışmaOran'] = df['Tahmin'] / df['Hedef']
df_clear = df[df['Hedef']!=0]
df_clear['ÇalışmaFark'] = np.abs(df_clear['ÇalışmaOranı'] - df_clear['TahminÇalışmaOran'])
df_clear
# Out:
#          Tarih     GünAdı  Yapılan  Hedef  ÇalışmaOranı  FreeDay  OffDay  \
# 0   2022-12-05  Pazartesi        5      6          0.83        0       0
# 1   2022-12-06       Salı        3      6          0.50        0       0
# 3   2022-12-08   Perşembe        0      6          0.00        0       0
# 4   2022-12-09       Cuma        0      6          0.00        0       0
# 5   2022-12-10  Cumartesi        0      6          0.00        0       0
# 6   2022-12-11      Pazar        0      6          0.00        0       0
# 7   2022-12-12  Pazartesi        2      6          0.33        0       0
# 8   2022-12-13       Salı        2      6          0.33        0       0
# 9   2022-12-14   Çarşamba        4      6          0.67        0       0
# 10  2022-12-15   Perşembe        3      6          0.50        0       0
# 11  2022-12-16       Cuma        3      6          0.50        0       0
# 14  2022-12-19  Pazartesi        5      6          0.83        0       0
# ...

# %%
df_clear.loc[df_clear['TahminÇalışmaOran'] == df_clear['TahminÇalışmaOran'].max()]
# Out:
#          Tarih GünAdı  Yapılan  Hedef  ÇalışmaOranı  FreeDay  OffDay  Tahmin  \
# 34  2023-01-08  Pazar        2      2          1.00        1       0    1.09
# 104 2023-03-19  Pazar        2      2          1.00        1       0    1.09
#
#      Dif  TahminÇalışmaOran  ÇalışmaFark
# 34  0.91               0.54         0.46
# 104 0.91               0.54         0.46

# %%
df_clear.loc[df_clear['TahminÇalışmaOran'] == df_clear['TahminÇalışmaOran'].min()]
# Out:
#          Tarih     GünAdı  Yapılan  Hedef  ÇalışmaOranı  FreeDay  OffDay  \
# 20  2022-12-25      Pazar        2      2          1.00        0       0
# 21  2022-12-26  Pazartesi        4      2          2.00        0       0
# 122 2023-04-06   Perşembe        2      2          1.00        0       0
# 221 2023-07-14       Cuma        0      2          0.00        0       0
# 232 2023-07-25       Salı        0      2          0.00        0       0
# 243 2023-08-05  Cumartesi        0      2          0.00        0       0
#
#      Tahmin  Dif  TahminÇalışmaOran  ÇalışmaFark
# 20     0.99 1.01               0.49         0.51
# 21     0.99 3.01               0.49         1.51
# 122    0.99 1.01               0.49         0.51
# 221    0.99 0.99               0.49         0.49
# 232    0.99 0.99               0.49         0.49
# 243    0.99 0.99               0.49         0.49

# %%
df_clear['TahminÇalışmaOran'].mean()
# Out:
# 0.5230234546525486

# %%
end = datetime.datetime.now()
print("Proje Çalışma Süresi: ", (end-start))
# Out:
# Proje Çalışma Süresi:  0:00:11.891498
